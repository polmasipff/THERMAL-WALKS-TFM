# %% [markdown]
# # 04 · Results summary
#
# Notebook final per construir scorecards, elbow-like plots i conclusions breus.

# %%
import pandas as pd, numpy as np
from utils_plots import plot_grouping_scorecard

ml = pd.read_csv("csvs/ml_benchmark_results.csv")
parts = pd.read_csv("csvs/comfort_partition_search.csv")
ml.head(50)

# %%
parts.sort_values(["bal_acc_adj_chance","bal_acc_mean","f1_macro_mean"], ascending=False).head(15)

# %%
plot_grouping_scorecard(
    parts.head(50),
    metric="bal_acc_adj_chance",
    title="Top partition search results",
    output_path="figures/partition_scorecard_top20.png"
)
